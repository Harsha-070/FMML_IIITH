# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha-070/FMML_IIITH/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 16:36:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  90.8MB/s    in 0.8s
#
# 2024-03-29 16:36:17 (90.8 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5247    1204.1276v4  We obtain a tight distribution-specific charac...  stat
# 22576  1701.05306v2  Estimation of individual treatment effect in o...  stat
# 24372   1311.1223v1  Image fusion is to reduce uncertainty and mini...    cs
# 4604    1301.3861v1  Inference for belief networks using Gibbs samp...    cs
# 11314  1508.07643v3  In this paper we introduce a novel family of d...  stat
# ...             ...                                                ...   ...
# 12075  1707.05807v1  The pairwise influence matrix of Dobrushin has...  stat
# 13891  1603.08146v1  A draft memory model (DM) for neural networks ...    cs
# 33182  1803.03503v1  The subject of deep learning has recently attr...    cs
# 11007   1310.2931v2  A predictor that is deployed in a live product...  stat
# 11820  1702.04126v3  We consider the problem of sequential learning...  stat
#
#                                                    title  year  \
# 5247   Distribution-Dependent Sample Complexity of La...  2012
# 22576  Estimating Individual Treatment Effect in Obse...  2017
# 24372  Quality Assessment of Pixel-Level ImageFusion ...  2013
# 4604   Inference for Belief Networks Using Coupling F...  2013
# 11314                         Directional Decision Lists  2015
# ...                                                  ...   ...
# 12075     Improving Gibbs Sampler Scan Quality with DoGS  2017
# 13891  A Draft Memory Model on Spiking Neural Assemblies  2016
# 33182  Construction of neural networks for realizatio...  2018
# 11007             Feedback Detection for Live Predictors  2013
# 11820  Gaussian-Dirichlet Posterior Dominance in Sequ...  2017
#
#                                                 keywords
# 5247   [distribution, characterization, complexity, c...
# 22576  [estimation, individual, treatment, observatio...
# 24372  [uncertainty, redundancy, maximizing, informat...
# 4604   [inference, distribution, unobserved, variable...
# 11314  [introduce, consisting, interpretable, efficie...
# ...                                                  ...
# 12075  [influence, dobrushin, analytical, convergence...
# 13891  [propagation, described, immediately, presente...
# 33182  [attracted, disciplines, including, diagnosis,...
# 11007  [predictor, production, predictions, fulfillin...
# 11820  [sequential, categorical, observations, establ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5247     [distribution, characterization, complexity, c...
# 22576    [estimation, individual, treatment, observatio...
# 24372    [uncertainty, redundancy, maximizing, informat...
# 4604     [inference, distribution, unobserved, variable...
# 11314    [introduce, consisting, interpretable, efficie...
#                                ...
# 3455     [resonance, reconstruction, demanding, intensi...
# 14561    [deficiencies, resources, processing, applicat...
# 22745    [processes, approximation, calibrated, predict...
# 35226    [levelwise, algorithm, following, candidate, g...
# 28691    [algorithms, estimation, principled, benchmark...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8824 words.
# Out of those 4560 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9cb6db5b-04dc-4952-a884-7d69c6b33261" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cb6db5b-04dc-4952-a884-7d69c6b33261")) {                    Plotly.newPlot(                        "9cb6db5b-04dc-4952-a884-7d69c6b33261",                        [{"x":["dependent","eigenvalue","properties","generated","shattering","statistics","regularization","distributions","independent","connections","characterizes","distribution","quantitatively","dimension","characterization","variables","classification","universal","introduce","classifiers","effectiveness","complexity","estimation","methodology","comparative","framework","individual","hypothetical","promising","heterogeneous","selection","treatments","especially","illustrate","treatment","inferential","synthetic","complicated","challenges","estimating","confounding","important","observational","counterfactual","registered","information","applications","processing","assessment","transform","abbreviated","algorithm","maximizing","concealed","composite","performance","evaluation","biometrics","parameters","algorithms","perception","redundancy","informative","detection","different","forecasting","uncertainty","unobserved","simulation","convergence","imprecise","asymptotically","considering","explicitly","simulations","inference","intractable","practical","empirically","simulated","direction","monotonically","consisting","usability","directional","efficiently","particular","decreasing","probabilities","exemplify","interpretable","identifying","manufacturing","resistance","efficient","challenging","pertinence","determine","systematic","application","measurements","replicated","respectively","discrimination","methodologies","collected","subjective","expressed","localized","potential","judgement","automatic","dimensional","electrodes","excellent","polarization","nonlinearity","experimental","recommender","literature","rectangular","represented","technique","performed","containing","movielens","personalized","predicting","evaluations","factorization","databases","nonnegative","observations","recommendations","numerical","interactions","variational","demonstrate","hyperparameter","approximation","hierarchical","providing","objective","specifically","optimized","associates","comparisons","implicitly","representation","generative","groundtruth","automatically","overfitting","multilinear","capturing","extensive","experiments","predictive","underlying","independently","effectively","perspectives","incomplete","considered","convergent","furthermore","celebrated","developed","including","straightforward","demonstrated","introducing","implement","criterion","inpainting","considers","theoretically","monotonic","recovered","completion","empirical","optimization","theoretical","reproducing","embeddings","instantiations","foundations","differentially","mechanisms","scenarios","embedding","generating","construct","resulting","consistent","definition","guaranteeing","estimators","available","differential"],"y":[72,3,193,174,1,65,68,105,115,63,11,193,34,58,20,144,507,43,338,128,204,247,200,75,36,503,110,4,117,32,166,7,123,78,33,1,137,35,109,58,2,392,17,3,9,704,436,292,48,63,3,833,30,2,10,867,235,8,241,618,51,21,36,320,764,11,88,10,68,114,6,12,61,74,47,198,30,137,82,58,62,3,66,8,20,168,284,7,49,2,38,64,6,2,403,273,2,79,33,220,56,3,79,16,16,84,32,33,15,153,3,165,170,1,25,2,3,382,19,137,7,87,284,137,59,2,12,78,53,44,73,8,82,17,69,76,45,528,10,97,105,82,189,174,54,5,33,24,370,127,2,178,29,4,46,169,590,56,138,34,117,16,28,130,3,146,1,202,278,15,109,56,68,42,10,41,46,8,7,25,137,317,150,10,72,5,8,6,70,97,118,96,84,158,78,31,9,9,284,31],"type":"bar"},{"x":["dependent","eigenvalue","properties","generated","s ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4560,), (4560, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Multiple</span> <span style=''>Tasks</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multilinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Relationship</span> <span style=''>Networks</span> <br/><br/><span style=''>Deep</span> <span style=''>networks</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style=''>can</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>transferable</span> <span style=''>features</span> <span style=''>to</span> <span style=''>promote</span> <span style=''>learning</span> <span style=''>multiple</span> <span style=''>tasks</span> <span style=''>Since</span> <span style=''>deep</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 0.49999999999999994);'>eventually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>from</span> <span style=''>general</span> <span style=''>to</span> <span style=''>specific</span> <span style=''>along</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>how</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>task</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>relatedness</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.30952380952380953);'>parameter</span> <span style=''>tensors</span> <span style=''>and</span> <span style=''>improve</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>transferability</span> <span style=''>in</span> <span style=''>the</span> <span style=''>multiple</span> <span style=''>task</span> <span style=''>specific</span> <span style=''>layers</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multilinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Relationship</span> <span style=''>Networks</span> <span style=''>(MRN)</span> <span style=''>that</span> <span style=''>discover</span> <span style=''>the</span> <span style=''>task</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>based</span> <span style=''>on</span> <span style=''>novel</span> <span style=''>tensor</span> <span style=''>normal</span> <span style=''>priors</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.30952380952380953);'>parameter</span> <span style=''>tensors</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>task</span> <span style=''>specific</span> <span style=''>layers</span> <span style=''>in</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.6280087527352297);'>convolutional</span> <span style=''>networks</span> <span style=''>By</span> <span style=''>jointly</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>transferable</span> <span style=''>features</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multilinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>of</span> <span style=''>tasks</span> <span style=''>and</span> <span style=''>features</span> <span style=''>MRN</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>To</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>we</span> <span style=''>need</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>kernel</span> <span style=''>learning</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Generalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>become</span> <span style=''>a</span> <span style=''>subject</span> <span style=''>of</span> <span style=''>intense</span> <span style=''>study</span> <span style=''>Heavily</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrized</span> <span style=''>deep</span> <span style=''>models</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>fit</span> <span style=''>training</span> <span style=''>data</span> <span style=''>exactly</span> <span style=''>Despite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitting</span> <span style=''>they</span> <span style=''>perform</span> <span style=''>well</span> <span style=''>on</span> <span style=''>test</span> <span style=''>data</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>phenomenon</span> <span style=''>not</span> <span style=''>yet</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style=''>The</span> <span style=''>first</span> <span style=''>point</span> <span style=''>of</span> <span style=''>our</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>that</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>is</span> <span style=''>not</span> <span style=''>a</span> <span style=''>unique</span> <span style=''>feature</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>Using</span> <span style=''>real</span> <span style=''>world</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>datasets</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>that</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>have</span> <span style=''>zero</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>error</span> <span style=''>(overfitting)</span> <span style=''>or</span> <span style=''>even</span> <span style=''>zero</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>error</span> <span style=''>(interpolation)</span> <span style=''>perform</span> <span style=''>very</span> <span style=''>well</span> <span style=''>on</span> <span style=''>test</span> <span style=''>data</span> <span style=''>We</span> <span style=''>proceed</span> <span style=''>to</span> <span style=''>prove</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>norm</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>for</span> <span style=''>smooth ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Consistent</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>Bootstrap</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>least</span> <span style=''>square</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.49486652977412743);'>regression</span> <span style=''>problem</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.4035087719298245);'>regularization</span> <span style=''>by</span> <span style=''>the</span> <span style=''>ell1</span> <span style=''>norm</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>usually</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style=''>present</span> <span style=''>a</span> <span style=''>detailed</span> <span style='background-color:rgba(255, 0, 0, 0.6822429906542057);'>asymptotic</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>in</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.39609236234458267);'>dimensional</span> <span style=''>settings</span> <span style=''>For</span> <span style=''>various</span> <span style=''>decays</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4035087719298245);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.30952380952380953);'>parameter</span> <span style=''>we</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.6822429906542057);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>equivalents</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>correct</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>For</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>rate</span> <span style=''>decay</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>selects</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3191489361702127);'>variables</span> <span style=''>that</span> <span style=''>should</span> <span style=''>enter</span> <span style=''>the</span> <span style=''>model</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>tending</span> <span style=''>to</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponentially</span> <span style=''>fast</span> <span style=''>while</span> <span style=''>it</span> <span style=''>selects</span> <span style=''>all</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3191489361702127);'>variables</span> <span style=''>with</span> <span style=''>strictly</span> <span style=''>positive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>property</span> <span style=''>implies< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Completion</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Factorizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Polynomials</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Predicting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unobserved</span> <span style=''>entries</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style=''>matrix</span> <span style=''>has</span> <span style=''>found</span> <span style=''>wide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicability</span> <span style=''>in</span> <span style=''>several</span> <span style=''>areas</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommender</span> <span style=''>systems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>biology</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>Many</span> <span style=''>scalable</span> <span style=''>methods</span> <span style=''>with</span> <span style=''>rigorous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>where</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>factored</span> <span style=''>into</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>are</span> <span style=''>learned</span> <span style=''>for</span> <span style=''>the</span> <span style=''>row</span> <span style=''>and</span> <span style=''>column</span> <span style=''>entities</span> <span style=''>While</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style=''>recent</span> <span style=''>research</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>explicit</span> <span style=''>side</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>in</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>setting</span> <span style=''>often</span> <span style=''>implicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>can</span> <span style=''>be</span> <span style=''>gleaned</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>via</span> <span style=''>higher</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>among</span> <span style=''>entities</span> <span style=''>Such</span> <span style=''>implicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>useful</span> <span style=''>in</span> <span style=''>cases</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style=''>very</span> <span style=''>sparse</span> <span style=''>as</span> <span style=''>is</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.07918308849874597)
# 	experimental (0.13686850591185956)
# 	representation (0.13256897169473308)
# 	processing (0.10462199928341097)
# 	segmentation (0.07631673235399498)
# 	detection (0.11465424579003941)
# 	information (0.2522393407380867)
# 	different (0.2737370118237191)
# 	recognition (0.12898602651379434)
# 	convolutional (0.13328556073092082)
#
# Some Statistics words are:
# 	algorithm (0.3797909407665505)
# 	stochastic (0.12742658038825286)
# 	variables (0.13887506222000995)
# 	statistical (0.1483325037332006)
# 	theoretical (0.1493280238924838)
# 	estimation (0.17023394723743157)
# 	inference (0.18168242906918866)
# 	distribution (0.1831757093081135)
# 	dimensional (0.19561971129915381)
# 	regression (0.18118466898954705)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="38306429-5011-4f29-a745-2f3b8b6c2528" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38306429-5011-4f29-a745-2f3b8b6c2528")) {                    Plotly.newPlot(                        "38306429-5011-4f29-a745-2f3b8b6c2528",                        [{"x":["dependent","eigenvalue","properties","generated","shattering","statistics","regularization","distributions","independent","connections","characterizes","distribution","quantitatively","dimension","characterization","variables","classification","universal","introduce","classifiers","effectiveness","complexity","estimation","methodology","comparative","framework","individual","hypothetical","promising","heterogeneous","selection","treatments","especially","illustrate","treatment","inferential","synthetic","complicated","challenges","estimating","confounding","important","observational","counterfactual","registered","information","applications","processing","assessment","transform","abbreviated","algorithm","maximizing","concealed","composite","performance","evaluation","biometrics","parameters","algorithms","perception","redundancy","informative","detection","different","forecasting","uncertainty","unobserved","simulation","convergence","imprecise","asymptotically","considering","explicitly","simulations","inference","intractable","practical","empirically","simulated","direction","monotonically","consisting","usability","directional","efficiently","particular","decreasing","probabilities","exemplify","interpretable","identifying","manufacturing","resistance","efficient","challenging","pertinence","determine","systematic","application","measurements","replicated","respectively","discrimination","methodologies","collected","subjective","expressed","localized","potential","judgement","automatic","dimensional","electrodes","excellent","polarization","nonlinearity","experimental","recommender","literature","rectangular","represented","technique","performed","containing","movielens","personalized","predicting","evaluations","factorization","databases","nonnegative","observations","recommendations","numerical","interactions","variational","demonstrate","hyperparameter","approximation","hierarchical","providing","objective","specifically","optimized","associates","comparisons","implicitly","representation","generative","groundtruth","automatically","overfitting","multilinear","capturing","extensive","experiments","predictive","underlying","independently","effectively","perspectives","incomplete","considered","convergent","furthermore","celebrated","developed","including","straightforward","demonstrated","introducing","implement","criterion","inpainting","considers","theoretically","monotonic","recovered","completion","empirical","optimization","theoretical","reproducing","embeddings","instantiations","foundations","differentially","mechanisms","scenarios","embedding","generating","construct","resulting","consistent","definition","guaranteeing","estimators","available","differential","population","consistency","protected","contributing","constructed","controlling","releasing","attention","recognition","scattering","principal","predefined","extraction","convolutional","translation","component","frequency","invariant","dimensionality","fingerprint","architecture","transforms","descriptors","outperforms","competing","guarantees","estimator","conditional","functional","established","nonparametric","parameter","generally","competitive","exponential","generalized","generalizes","transitions","specified","introduced","heteroscedasticity","benchmark","reinforcement","complementary","community","improvements","extensions","contribution","combination","combining","efficiency","fruitfully ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	eigendecomposition
# 	seriously
# 	precautions
# 	deconvnet
# 	pseudolikelihood
# 	unregularized
# 	disconnected
# 	polyhedral
# 	connectomics
# 	emphsparse
# 	katehakis
# 	minimizers
# 	rewritten
# 	equitability
# 	equitable
# 	gaussianity
# 	parallelize
# 	molecules
# 	applicative
# 	biophysical
# Some words which never appear in Statistics papers:
# 	abbreviated
# 	concealed
# 	biometrics
# 	pertinence
# 	judgement
# 	polarization
# 	groundtruth
# 	fruitfully
# 	earthquake
# 	organizations
# 	relatedness
# 	localizing
# 	traumatic
# 	navigation
# 	navigational
# 	caenorhabditis
# 	rotations
# 	hallucination
# 	confluence
# 	nonuniform

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079765937788728e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
